# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
dl = pd.read_excel("/Users/azamkhan/speckled/research speckled/baseline experiments.xlsx", sheet_name="Sheet2", engine='openpyxl')

# %%
dl = dl.set_index("Future Timesteps")

# %%
dl
# Out:
#                   Baseline   LSTM    GRU
# Future Timesteps
# 6                    19.30  18.17  19.21
# 9                    25.30  22.44  23.83
# 12                   33.95  27.07  28.31

# %%
ax = dl.plot(ylabel="MAPE", figsize=(7, 5))

fig = ax.get_figure()
fig.savefig('delhi.png', dpi=300)

# %%
le = pd.read_excel("/Users/azamkhan/speckled/research speckled/baseline experiments.xlsx", sheet_name="Sheet3", engine='openpyxl')

# %%
le = le.set_index("Future Timesteps")

# %%
le = le.drop("Unnamed: 3", axis=1)

# %%
le
# Out:
#                   Baseline   LSTM    GRU
# Future Timesteps
# 6                    31.36  23.59  23.91
# 9                    35.47  26.42  27.88
# 12                   41.88  28.58  29.95

# %%
ax = le.plot(ylabel="MAPE", figsize=(7, 5))

fig = ax.get_figure()
fig.savefig('leon.png', dpi=300)

# %%
gd = pd.read_excel("/Users/azamkhan/speckled/research speckled/baseline experiments.xlsx", sheet_name="Sheet4", engine='openpyxl')

# %%
gd = gd.set_index("Future Timesteps")

# %%
gd
# Out:
#                   Baseline   LSTM    GRU
# Future Timesteps
# 6                    30.38  23.45  23.79
# 9                    35.44  27.27  27.91
# 12                   41.58  29.92  30.39

# %%
ax = gd.plot(ylabel="MAPE", figsize=(7, 5))

fig = ax.get_figure()
fig.savefig('guadalajara.png', dpi=300)
