# %% [markdown]
# # Importing libraries

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization, LSTM, TimeDistributed, Reshape
from tensorflow.keras.layers import MaxPool2D, MaxPooling2D, MaxPooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow import keras

from tensorflow.keras.callbacks import CSVLogger, EarlyStopping
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
from tensorboard.plugins.hparams import api as hp

# %% [markdown]
# # Loading Files

# %%
peeps = pd.read_csv("../preprocessing/peeps_test.csv")
peeps = peeps[~peeps.duplicated()]
peeps = peeps.set_index('timestamp')
peeps = peeps.drop(['UUID', 'temperature'], axis=1)
peeps = peeps.dropna()

# %%
leon = pd.read_csv("../preprocessing/leon_stationary.csv")
leon = leon[~leon.duplicated()]
leon = leon.set_index('timestamp')
leon = leon.drop(['UUID', 'temperature'], axis=1)
leon = leon.dropna()

# %%
guadalajara = pd.read_csv("../preprocessing/guadalajara_stationary.csv")
guadalajara = guadalajara[~guadalajara.duplicated()]
guadalajara = guadalajara.set_index('timestamp')
guadalajara = guadalajara.drop(['UUID', 'temperature'], axis=1)
guadalajara = guadalajara.dropna()

# %% [markdown]
# # Functions

# %%
def ms_temporal_set(dataset, window_size, future_target, split):
    split_percent = split
    split = int(split_percent*len(dataset))
    
    data = dataset.values
    
    def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
        data = []
        labels = []

        start_index = start_index + history_size
        if end_index is None:
            end_index = len(dataset) - target_size

        for i in range(start_index, end_index):
            indices = range(i-history_size, i, step)
            data.append(dataset[indices])

            if single_step:
                labels.append(target[i+target_size])
            else:
                labels.append(target[i:i+target_size])

        return np.array(data), np.array(labels)
    
    past_history = window_size
    future_target = future_target
    STEP=1


    X_train, y_train = multivariate_data(data, data[:, 0], 0,
                                                       split, past_history,
                                                       future_target, STEP)
    X_test, y_test = multivariate_data(data, data[:, 0],
                                                   split, None, past_history,
                                                   future_target, STEP)
    
    return X_train, y_train, X_test, y_test

# %% [markdown]
# # Hyper-parameter Tuning, 1 Layer

# %% [markdown]
# ## Peeps

# %%
# %load_ext tensorboard

# %%
rm -rf ./logs/

# %%
HP_NUM_PREV = hp.HParam('num_prev', hp.Discrete([3,6,9,12]))
HP_NUM_FUT = hp.HParam('num_future', hp.Discrete([6,9,12]))
HP_LSTM_UNITS = hp.HParam('num_lstm', hp.Discrete([1, 20, 50, 100, 200]))
HP_DENSE_UNITS = hp.HParam('num_dense', hp.Discrete([5, 10, 15, 20, 100]))


METRIC_MAE = 'mean_absolute_error'

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
    hp.hparams_config(
    hparams=[HP_NUM_PREV, HP_NUM_FUT, HP_LSTM_UNITS,HP_DENSE_UNITS],
    metrics=[hp.Metric(METRIC_MAE, display_name='MAE')],
  )

# %%
def two_layer_lstm(hparams, dataset):
    
    df = dataset
    future_target = hparams[HP_NUM_FUT]
    X_train, y_train, X_test, y_test = ms_temporal_set(df, hparams[HP_NUM_PREV], future_target, 0.7)

    model = Sequential()
    model.add(LSTM(units = hparams[HP_LSTM_UNITS], activation='relu', input_shape=X_train.shape[-2:]))
    model.add(LSTM(units = hparams[HP_LSTM_UNITS], activation='relu'))
    model.add(Dense(hparams[HP_DENSE_UNITS], activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.1)))
    model.add(Dense(future_target))

    model.compile(optimizer='adam', loss='mae')
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
    #print(model.summary())
    model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=0,validation_split = (14/86), callbacks=[callback])
    
    y_pred = model.predict(X_test)
    
    y_pred = y_pred[:,future_target-1]
    y_test = y_test[:,future_target-1]

    mae = mean_absolute_error(y_test, y_pred)
        
    return mae

# %%
def one_layer_lstm(hparams,dataset):
    
    df = dataset
    future_target = hparams[HP_NUM_FUT]
    X_train, y_train, X_test, y_test = ms_temporal_set(df, hparams[HP_NUM_PREV], future_target, 0.7)


    model = Sequential()
    model.add(LSTM(units = hparams[HP_LSTM_UNITS], activation='relu', input_shape=X_train.shape[-2:]))
    model.add(Dense(hparams[HP_DENSE_UNITS], activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.1)))
    model.add(Dense(future_target))

    model.compile(optimizer='adam', loss = 'mean_absolute_error')
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
    model.fit(X_train, y_train, epochs=100, verbose = 0,validation_split = (14/86), callbacks=[callback])

    y_pred = model.predict(X_test)
    
    y_pred = y_pred[:,future_target-1]
    y_test = y_test[:,future_target-1]

    mae = mean_absolute_error(y_test, y_pred)
        
    return mae

# %%
def run(run_dir, hparams, dataset):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
       
        mae = one_layer_lstm(hparams, dataset)
        tf.summary.scalar(METRIC_MAE, mae, step=1)

# %%
session_num = 0

for num_prev in HP_NUM_PREV.domain.values:
    for num_fut in HP_NUM_FUT.domain.values:
        for num_lstm in HP_LSTM_UNITS.domain.values:
            for num_dense in HP_DENSE_UNITS.domain.values:
                hparams = {
                  HP_NUM_PREV: num_prev,
                  HP_NUM_FUT: num_fut,
                  HP_LSTM_UNITS: num_lstm,
                  HP_DENSE_UNITS: num_dense,  
                }
                run_name = "peeps-run-%d" % session_num
                print('--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                run('logs/hparam_tuning/' + run_name, hparams, peeps)
                session_num += 1
# Out:
# --- Starting trial: peeps-run-0
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: peeps-run-1
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}

# %%
tensorboard --logdir logs/hparam_tuning
# Out:
# Reusing TensorBoard on port 6006 (pid 6706), started 0:02:04 ago. (Use '!kill 6706' to kill it.)
#       <iframe id="tensorboard-frame-d00dbd3e0a26104" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d00dbd3e0a26104");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Leon

# %%
rm -rf ./logs/

# %%
session_num = 0

for num_prev in HP_NUM_PREV.domain.values:
    for num_fut in HP_NUM_FUT.domain.values:
        for num_lstm in HP_LSTM_UNITS.domain.values:
            for num_dense in HP_DENSE_UNITS.domain.values:
                hparams = {
                  HP_NUM_PREV: num_prev,
                  HP_NUM_FUT: num_fut,
                  HP_LSTM_UNITS: num_lstm,
                  HP_DENSE_UNITS: num_dense,  
                }
                run_name = "leon-run-%d" % session_num
                print('--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                run('logs/hparam_tuning/' + run_name, hparams, leon)
                session_num += 1
# Out:
# --- Starting trial: leon-run-0
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-1
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-2
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-3
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-4
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-5
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-6
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-7
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-8
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-9
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-10
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-11
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-12
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-13
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-14
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-15
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-16
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-17
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-18
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-19
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-20
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-21
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-22
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-23
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-24
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-25
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-26
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-27
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-28
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-29
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-30
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-31
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-32
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-33
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-34
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-35
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-36
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-37
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-38
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-39
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-40
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-41
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-42
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-43
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-44
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-45
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-46
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-47
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-48
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-49
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-50
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-51
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-52
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-53
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-54
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-55
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-56
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-57
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-58
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-59
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-60
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-61
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-62
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-63
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-64
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-65
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-66
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-67
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-68
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-69
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-70
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-71
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-72
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-73
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-74
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-75
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-76
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-77
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-78
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-79
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-80
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-81
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-82
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-83
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-84
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-85
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-86
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-87
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-88
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-89
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-90
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-91
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-92
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-93
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-94
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-95
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-96
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-97
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-98
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-99
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-100
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-101
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-102
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-103
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-104
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-105
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-106
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-107
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-108
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-109
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-110
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-111
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-112
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-113
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-114
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-115
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-116
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-117
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-118
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-119
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-120
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-121
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-122
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-123
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-124
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-125
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-126
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-127
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-128
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-129
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-130
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-131
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-132
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-133
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-134
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-135
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-136
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-137
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-138
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-139
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-140
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-141
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-142
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-143
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-144
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-145
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-146
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-147
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-148
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-149
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-150
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-151
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-152
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-153
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-154
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-155
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-156
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-157
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-158
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-159
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-160
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-161
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-162
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-163
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-164
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-165
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-166
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-167
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-168
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-169
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-170
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-171
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-172
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-173
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-174
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-175
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-176
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-177
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-178
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-179
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-180
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-181
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-182
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-183
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-184
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-185
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-186
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-187
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-188
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-189
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-190
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-191
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-192
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-193
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-194
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-195
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-196
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-197
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-198
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-199
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-200
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-201
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-202
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-203
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-204
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-205
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-206
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-207
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-208
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-209
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-210
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-211
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-212
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-213
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-214
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-215
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-216
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-217
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-218
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-219
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-220
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-221
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-222
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-223
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-224
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-225
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-226
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-227
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-228
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-229
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-230
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-231
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-232
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-233
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-234
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-235
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-236
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-237
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-238
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-239
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-240
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-241
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-242
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-243
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-244
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-245
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-246
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-247
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-248
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-249
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-250
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-251
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-252
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-253
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-254
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-255
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-256
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-257
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-258
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-259
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-260
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-261
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-262
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-263
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-264
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-265
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-266
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-267
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-268
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-269
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-270
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-271
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-272
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-273
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-274
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-275
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-276
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-277
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-278
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-279
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-280
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-281
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-282
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-283
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-284
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-285
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-286
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-287
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-288
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-289
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-290
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-291
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-292
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-293
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-294
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-295
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-296
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-297
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-298
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-299
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-300
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-301
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-302
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-303
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-304
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-305
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-306
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-307
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-308
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-309
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-310
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-311
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-312
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-313
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-314
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-315
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-316
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-317
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-318
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-319
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-320
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-321
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-322
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-323
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-324
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-325
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-326
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-327
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-328
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-329
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-330
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-331
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-332
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-333
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-334
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-335
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-336
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-337
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-338
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-339
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-340
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-341
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-342
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-343
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-344
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-345
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-346
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-347
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-348
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-349
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: leon-run-350
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: leon-run-351
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: leon-run-352
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: leon-run-353
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: leon-run-354
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: leon-run-355
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: leon-run-356
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: leon-run-357
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: leon-run-358
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: leon-run-359
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: leon-run-360
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: leon-run-361
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: leon-run-362
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: leon-run-363
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: leon-run-364
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: leon-run-365
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: leon-run-366
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: leon-run-367
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: leon-run-368
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: leon-run-369
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: leon-run-370
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: leon-run-371
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: leon-run-372
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: leon-run-373
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: leon-run-374
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 200, 'num_dense': 100}

# %%
# %tensorboard --logdir logs/hparam_tuning
# Out:
# Reusing TensorBoard on port 6006 (pid 22752), started 11:43:30 ago. (Use '!kill 22752' to kill it.)
#       <iframe id="tensorboard-frame-21f7a0b7183eb39c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-21f7a0b7183eb39c");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Guadalajara

# %%
rm -rf ./logs/

# %%
session_num = 0

for num_prev in HP_NUM_PREV.domain.values:
    for num_fut in HP_NUM_FUT.domain.values:
        for num_lstm in HP_LSTM_UNITS.domain.values:
            for num_dense in HP_DENSE_UNITS.domain.values:
                hparams = {
                  HP_NUM_PREV: num_prev,
                  HP_NUM_FUT: num_fut,
                  HP_LSTM_UNITS: num_lstm,
                  HP_DENSE_UNITS: num_dense,  
                }
                run_name = "guadalajara-run-%d" % session_num
                print('--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                run('logs/hparam_tuning/' + run_name, hparams, guadalajara)
                session_num += 1
# Out:
# --- Starting trial: guadalajara-run-0
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-1
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-2
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-3
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-4
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-5
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-6
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-7
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-8
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-9
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-10
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-11
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-12
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-13
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-14
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-15
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-16
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-17
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-18
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-19
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-20
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-21
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-22
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-23
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-24
# {'num_prev': 1, 'num_future': 6, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-25
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-26
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-27
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-28
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-29
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-30
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-31
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-32
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-33
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-34
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-35
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-36
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-37
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-38
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-39
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-40
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-41
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-42
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-43
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-44
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-45
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-46
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-47
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-48
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-49
# {'num_prev': 1, 'num_future': 9, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-50
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-51
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-52
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-53
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-54
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-55
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-56
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-57
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-58
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-59
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-60
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-61
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-62
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-63
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-64
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-65
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-66
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-67
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-68
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-69
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-70
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-71
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-72
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-73
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-74
# {'num_prev': 1, 'num_future': 12, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-75
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-76
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-77
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-78
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-79
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-80
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-81
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-82
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-83
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-84
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-85
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-86
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-87
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-88
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-89
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-90
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-91
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-92
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-93
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-94
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-95
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-96
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-97
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-98
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-99
# {'num_prev': 3, 'num_future': 6, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-100
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-101
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-102
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-103
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-104
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-105
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-106
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-107
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-108
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-109
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-110
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-111
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-112
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-113
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-114
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-115
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-116
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-117
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-118
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-119
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-120
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-121
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-122
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-123
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-124
# {'num_prev': 3, 'num_future': 9, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-125
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-126
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-127
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-128
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-129
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-130
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-131
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-132
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-133
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-134
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-135
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-136
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-137
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-138
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-139
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-140
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-141
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-142
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-143
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-144
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-145
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-146
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-147
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-148
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-149
# {'num_prev': 3, 'num_future': 12, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-150
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-151
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-152
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-153
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-154
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-155
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-156
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-157
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-158
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-159
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-160
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-161
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-162
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-163
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-164
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-165
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-166
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-167
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-168
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-169
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-170
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-171
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-172
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-173
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-174
# {'num_prev': 6, 'num_future': 6, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-175
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-176
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-177
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-178
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-179
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-180
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-181
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-182
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-183
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-184
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-185
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-186
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-187
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-188
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-189
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-190
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-191
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-192
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-193
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-194
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-195
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-196
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-197
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-198
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-199
# {'num_prev': 6, 'num_future': 9, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-200
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-201
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-202
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-203
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-204
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-205
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-206
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-207
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-208
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-209
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-210
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-211
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-212
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-213
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-214
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-215
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-216
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-217
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-218
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-219
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-220
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-221
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-222
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-223
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-224
# {'num_prev': 6, 'num_future': 12, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-225
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-226
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-227
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-228
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-229
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-230
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-231
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-232
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-233
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-234
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-235
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-236
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-237
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-238
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-239
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-240
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-241
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-242
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-243
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-244
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-245
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-246
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-247
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-248
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-249
# {'num_prev': 9, 'num_future': 6, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-250
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-251
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-252
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-253
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-254
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-255
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-256
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-257
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-258
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-259
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-260
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-261
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-262
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-263
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-264
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-265
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-266
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-267
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-268
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-269
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-270
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-271
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-272
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-273
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-274
# {'num_prev': 9, 'num_future': 9, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-275
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-276
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-277
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-278
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-279
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-280
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-281
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-282
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-283
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-284
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-285
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-286
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-287
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-288
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-289
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-290
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-291
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-292
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-293
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-294
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-295
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-296
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-297
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-298
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-299
# {'num_prev': 9, 'num_future': 12, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-300
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-301
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-302
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-303
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-304
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-305
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-306
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-307
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-308
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-309
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-310
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-311
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-312
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-313
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-314
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-315
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-316
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-317
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-318
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-319
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-320
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-321
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-322
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-323
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-324
# {'num_prev': 12, 'num_future': 6, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-325
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-326
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-327
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-328
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-329
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-330
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-331
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-332
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-333
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-334
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-335
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-336
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-337
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-338
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-339
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-340
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-341
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-342
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-343
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-344
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-345
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-346
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-347
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-348
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-349
# {'num_prev': 12, 'num_future': 9, 'num_lstm': 200, 'num_dense': 100}
# --- Starting trial: guadalajara-run-350
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 1, 'num_dense': 5}
# --- Starting trial: guadalajara-run-351
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 1, 'num_dense': 10}
# --- Starting trial: guadalajara-run-352
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 1, 'num_dense': 15}
# --- Starting trial: guadalajara-run-353
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 1, 'num_dense': 20}
# --- Starting trial: guadalajara-run-354
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 1, 'num_dense': 100}
# --- Starting trial: guadalajara-run-355
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 20, 'num_dense': 5}
# --- Starting trial: guadalajara-run-356
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 20, 'num_dense': 10}
# --- Starting trial: guadalajara-run-357
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 20, 'num_dense': 15}
# --- Starting trial: guadalajara-run-358
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 20, 'num_dense': 20}
# --- Starting trial: guadalajara-run-359
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 20, 'num_dense': 100}
# --- Starting trial: guadalajara-run-360
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 50, 'num_dense': 5}
# --- Starting trial: guadalajara-run-361
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 50, 'num_dense': 10}
# --- Starting trial: guadalajara-run-362
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 50, 'num_dense': 15}
# --- Starting trial: guadalajara-run-363
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 50, 'num_dense': 20}
# --- Starting trial: guadalajara-run-364
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 50, 'num_dense': 100}
# --- Starting trial: guadalajara-run-365
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 100, 'num_dense': 5}
# --- Starting trial: guadalajara-run-366
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 100, 'num_dense': 10}
# --- Starting trial: guadalajara-run-367
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 100, 'num_dense': 15}
# --- Starting trial: guadalajara-run-368
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 100, 'num_dense': 20}
# --- Starting trial: guadalajara-run-369
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 100, 'num_dense': 100}
# --- Starting trial: guadalajara-run-370
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 200, 'num_dense': 5}
# --- Starting trial: guadalajara-run-371
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 200, 'num_dense': 10}
# --- Starting trial: guadalajara-run-372
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 200, 'num_dense': 15}
# --- Starting trial: guadalajara-run-373
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 200, 'num_dense': 20}
# --- Starting trial: guadalajara-run-374
# {'num_prev': 12, 'num_future': 12, 'num_lstm': 200, 'num_dense': 100}

# %%
# %tensorboard --logdir logs/hparam_tuning
